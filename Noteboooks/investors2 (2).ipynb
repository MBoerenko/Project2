# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from config import username, password, host, port

# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

import json
import psycopg2

# %%
# create an engine that can connect to local database
engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/postgres")
conn=engine.connect()

# %%
#read in billionaires from sql
billionaire_list = pd.read_sql('SELECT * FROM billionaires group by name order by name;',conn)

# %%
billionaire_list
# Out:
#                               name  rank  year company_founded  \
# 0             A. Jerrold Perenchio   663  2014            1955
# 1               Abdulla Al Futtaim   687  2014            1930
# 2     Abdulla bin Ahmad Al Ghurair   305  2014            1960
# 3                Abdullah Al Rajhi   731  2014            1957
# 4                 Abdulsamad Rabiu  1372  2014            1988
# ...                            ...   ...   ...             ...
# 1648                     Zhu Yicai  1154  2014            1993
# 1649                 Ziyad Manasir   609  2014            1992
# 1650            Ziyaudin Magomedov  1372  2014            2004
# 1651                  Zong Qinghou    94  2014            1987
# 1652            Zygmunt Solorz-Zak   446  2014            1992
#
#                company_name     company_relationship        company_sector  \
# 0                 Univision  former chairman and CEO                 media
# ...

# %%
#read in investors from sql
investors_list = pd.read_sql('SELECT * FROM investors;',conn)

# %%
investors_list
# Out:
#      investor_id                          name   location   type  \
# 0           1761       Ascent Venture Partners     Boston     vc
# 1            116             Baseline Ventures   Bay Area     vc
# 2           1968             Discovery Capital  Vancouver     vc
# 3           7877            Portland Seed Fund   Portland     vc
# 4           1677  Emerald Technology Ventures      Zurich     vc
# ..           ...                           ...        ...    ...
# 327         2125        Stata Venture Partners     Boston     vc
# 328         7668                 Evan Williams   Bay Area  angel
# 329         8623              George Kliavkoff   New York  angel
# 330         1615                    Shan Mehta   Bay Area  angel
# 331         8577                  Adii Pienaar  Cape Town  angel
#
#     most_recent_deal  number_of_deals  portfolio_size           city   state  \
# 0         2018-04-12                0               0         Boston      MA
# ...

# %%
#read in billionaires from sql
sharkTank_list = pd.read_sql('SELECT * FROM sharktank;',conn)

# %%
sharkTank_list
# Out:
#       deal                                        description  episode  \
# 0    False             Bluetooth device implant for your ear.        1
# 1     True  Retail and wholesale pie factory with two reta...        1
# 2     True  Ava the Elephant is a godsend for frazzled par...        1
# 3    False  Organizing, packing, and moving services deliv...        1
# 4    False  Interactive media centers for healthcare waiti...        1
# ..     ...                                                ...      ...
# 490   True  Zoom Interiors is a virtual service for interi...       28
# 491   True  Spikeball started out as a casual outdoors gam...       29
# 492   True  Shark Wheel is out to literally reinvent the w...       29
# 493  False  Adriana Montano wants to open the first Cat Ca...       29
# 494   True  Sway Motorsports makes a three-wheeled, all-el...       29
#
#                 category                                      entrepreneurs  \
# ...

# %%
rebeccas_list=pd.read_sql_query('SELECT * FROM investors_copy;',conn)

# %%
rebeccas_list
# Out:
#                       name company_founded                         industry  \
# 0     A. Jerrold Perenchio            1955                            media
# 1               Allan Gray            1973                 asset management
# 2             Andrej Babis            1993                     agriculteral
# 3              Ashwin Dani            1942                            paint
# 4            Bill Adderley            1979                        furniture
# ...                    ...             ...                              ...
# 2231       Robert Herjavec            2000                            Music
# 2232       Robert Herjavec            2000  Fitness Apparel and Accessories
# 2233       Robert Herjavec            2000               Outdoor Recreation
# 2234       Robert Herjavec            2000                       Automotive
# 2235       Robert Herjavec            2000                       Automotive
#
# ...

# %%
rebeccas_list.to_json('Data Sets\Json Files\investors.json',orient='records')

# %%
response = json.load(open('Data Sets\Json Files\investors.json', 'r'))

# %%
response
# Out:
# [{'name': 'A. Jerrold Perenchio',
#   'company_founded': '1955',
#   'industry': 'media',
#   'company_type': 'aquired',
#   'location': 'North America',
#   'wealth_worth_in_billions': 2.6,
#   'wealth_how_industry': 'Media',
#   'type_of_investor': 'angel',
#   'number_of_deals': None,
#   'portfolio_size': None,
#   'website': None,
#   'most_recent_deal': None},
#  {'name': 'Allan Gray',
#   'company_founded': '1973',
#   'industry': 'asset management',
#   'company_type': 'new',
#   'location': 'Sub-Saharan Africa',
#   'wealth_worth_in_billions': 1.3,
#   'wealth_how_industry': 'Other',
#   'type_of_investor': 'angel',
#   'number_of_deals': None,
#   'portfolio_size': None,
#   'website': None,
#   'most_recent_deal': None},
#  {'name': 'Andrej Babis',
#   'company_founded': '1993',
#   'industry': 'agriculteral',
#   'company_type': 'new',
#   'location': 'Europe',
#   'wealth_worth_in_billions': 2.4,
#   'wealth_how_industry': 'Consumer',
#   'type_of_investor': 'angel',
# ...

# %%
table1=pd.read_sql_query('SELECT name, wealth_worth_in_billions, portfolio_size FROM investors_copy;',conn)

# %%
table1
# Out:
#                       name  wealth_worth_in_billions  portfolio_size
# 0     A. Jerrold Perenchio                       2.6             NaN
# 1               Allan Gray                       1.3             NaN
# 2             Andrej Babis                       2.4             NaN
# 3              Ashwin Dani                       1.3             NaN
# 4            Bill Adderley                       1.8             NaN
# ...                    ...                       ...             ...
# 2231       Robert Herjavec                       0.2             NaN
# 2232       Robert Herjavec                       0.2             NaN
# 2233       Robert Herjavec                       0.2             NaN
# 2234       Robert Herjavec                       0.2             NaN
# 2235       Robert Herjavec                       0.2             NaN
#
# [2236 rows x 3 columns]
